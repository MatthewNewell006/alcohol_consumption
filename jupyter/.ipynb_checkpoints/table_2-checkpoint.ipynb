# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from cycler import cycler
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../data/table2.xls')

# %%
df.head(5)
# Out:
#   Table with row headers in column A and column headers in row 5 through 7  \
# 0                                         Table 2.
# 1  Income Distribution Measures Using Money Incom...
# 2  (For information on confidentiality protection...
# 3                                            Measure
# 4                                                NaN
#
#       Unnamed: 1 Unnamed: 2                      Unnamed: 3 Unnamed: 4  \
# 0            NaN        NaN                             NaN        NaN
# 1            NaN        NaN                             NaN        NaN
# 2            NaN        NaN                             NaN        NaN
# 3           2014        NaN                             NaN        NaN
# 4  Money income         NaN  Equivalence-\n adjusted income        NaN
#
#       Unnamed: 5 Unnamed: 6                      Unnamed: 7 Unnamed: 8  \
# 0            NaN        NaN                             NaN        NaN
# 1            NaN        NaN                             NaN        NaN
# 2            NaN        NaN                             NaN        NaN
# 3           2015        NaN                             NaN        NaN
# 4  Money income         NaN  Equivalence-\n adjusted income        NaN
#
#               Unnamed: 9  Unnamed: 10 Unnamed: 11  \
# 0                    NaN          NaN         NaN
# 1                    NaN          NaN         NaN
# 2                    NaN          NaN         NaN
# 3  Percentage change 2,*          NaN         NaN
# 4          Money income           NaN         NaN
#
#                       Unnamed: 12  Unnamed: 13 Unnamed: 14
# 0                             NaN          NaN         NaN
# 1                             NaN          NaN         NaN
# 2                             NaN          NaN         NaN
# 3                             NaN          NaN         NaN
# 4  Equivalence-\n adjusted income          NaN         NaN
