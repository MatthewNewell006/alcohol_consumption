# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from cycler import cycler
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('classic')

# %%
df = pd.read_csv('../data/modified/left_merge_table.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Unnamed: 0                             257 non-null    int64
#  1   ethanol_beer_gallons_per_capita        257 non-null    float64
#  2   ethanol_wine_gallons_per_capita        257 non-null    float64
#  3   ethanol_spirit_gallons_per_capita      257 non-null    float64
#  4   ethanol_all_drinks_gallons_per_capita  257 non-null    float64
#  5   number_of_beers                        257 non-null    float64
#  6   number_of_glasses_wine                 257 non-null    float64
#  7   number_of_shots_liquor                 257 non-null    float64
#  8   number_of_drinks_total                 257 non-null    float64
#  9   STATE                                  249 non-null    object
# ...

# %%
df
# Out:
#      Unnamed: 0  ethanol_beer_gallons_per_capita  \
# 0             0                             1.11
# 1             1                             1.11
# 2             2                             1.11
# 3             3                             1.11
# 4             4                             1.11
# ..          ...                              ...
# 252         252                             1.39
# 253         253                             1.25
# 254         254                             1.25
# 255         255                             1.25
# 256         256                             1.25
#
#      ethanol_wine_gallons_per_capita  ethanol_spirit_gallons_per_capita  \
# 0                               0.26                               0.64
# 1                               0.26                               0.64
# 2                               0.26                               0.64
# 3                               0.26                               0.64
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ethanol_beer_gallons_per_capita',
#        'ethanol_wine_gallons_per_capita', 'ethanol_spirit_gallons_per_capita',
#        'ethanol_all_drinks_gallons_per_capita', 'number_of_beers',
#        'number_of_glasses_wine', 'number_of_shots_liquor',
#        'number_of_drinks_total', 'STATE', 'ANN'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Unnamed: 0  ethanol_beer_gallons_per_capita  \
# count  257.000000                       257.000000
# mean   128.000000                         1.161907
# std     74.333707                         0.183023
# min      0.000000                         0.650000
# 25%     64.000000                         1.010000
# 50%    128.000000                         1.120000
# 75%    192.000000                         1.280000
# max    256.000000                         1.870000
#
#        ethanol_wine_gallons_per_capita  ethanol_spirit_gallons_per_capita  \
# count                       257.000000                         257.000000
# mean                          0.415992                           0.874825
# std                           0.166592                           0.236169
# min                           0.110000                           0.470000
# 25%                           0.300000                           0.710000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Unnamed: 0                             257 non-null    int64
#  1   ethanol_beer_gallons_per_capita        257 non-null    float64
#  2   ethanol_wine_gallons_per_capita        257 non-null    float64
#  3   ethanol_spirit_gallons_per_capita      257 non-null    float64
#  4   ethanol_all_drinks_gallons_per_capita  257 non-null    float64
#  5   number_of_beers                        257 non-null    float64
#  6   number_of_glasses_wine                 257 non-null    float64
#  7   number_of_shots_liquor                 257 non-null    float64
#  8   number_of_drinks_total                 257 non-null    float64
#  9   STATE                                  249 non-null    object
# ...

# %%
df['number_of_beers'].describe()
# Out:
# count    257.000000
# mean     275.415486
# std       43.383297
# min      154.070000
# 25%      239.410000
# 50%      265.480000
# 75%      303.410000
# max      443.260000
# Name: number_of_beers, dtype: float64

# %%
df['number_of_beers']
# Out:
# 0      263.11
# 1      263.11
# 2      263.11
# 3      263.11
# 4      263.11
#         ...
# 252    329.48
# 253    296.30
# 254    296.30
# 255    296.30
# 256    296.30
# Name: number_of_beers, Length: 257, dtype: float64

# %%
df.plot.hist(stacked = True, bins=5);

# %%
bs = df.loc[:,'number_of_beers']
bs.hist(bins=20,color='orange');

# %%
ss = df.loc[:,'number_of_shots_liquor']
ss.hist(bins=20,color='salmon');

# %%
ws = df.loc[:,'number_of_glasses_wine']
ws.hist(bins=20,color='deeppink');

# %%
total = df.loc[:,'number_of_drinks_total']
total.hist(bins=20,color='crimson');

# %%
bs = df.loc[:,'number_of_beers'].hist(bins=8, alpha = 0.8, color='wheat');
ss = df.loc[:,'number_of_shots_liquor'].hist(bins=15, alpha = 0.55, color = 'salmon');
ws = df.loc[:,'number_of_glasses_wine'].hist(bins=23, color='deeppink', alpha=0.35);
total = df.loc[:,'number_of_drinks_total'].hist(color = 'crimson');

# %%
fig, ax = plt.subplots(1,1)
# plt.figure()
ax.legend()
plt.title = "Alcohol Per Capita"
beer = df['ethanol_beer_gallons_per_capita'].diff().hist(color='orange', bins=5,alpha = 0.8)
wine =df['ethanol_wine_gallons_per_capita'].diff().hist(color='yellow', bins=5, alpha = 0.55)
spirits = df['ethanol_spirit_gallons_per_capita'].diff().hist(color='teal', bins=5,alpha = 0.35)
all_drinks = df['ethanol_all_drinks_gallons_per_capita'].diff().hist(color='green', bins=5, alpha = 0.2, label = "All Drinks / Gallons");
# Out:
# No handles with labels found to put in legend.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ethanol_beer_gallons_per_capita',
#        'ethanol_wine_gallons_per_capita', 'ethanol_spirit_gallons_per_capita',
#        'ethanol_all_drinks_gallons_per_capita', 'number_of_beers',
#        'number_of_glasses_wine', 'number_of_shots_liquor',
#        'number_of_drinks_total', 'STATE', 'ANN'],
#       dtype='object')
