# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from cycler import cycler
import matplotlib.pyplot as plt

# %% [markdown]
# <h3>Read in CSV File</h3>

# %%
df = pd.read_csv('../data/apparent_per_capita_alcohol_consumption_1977_2018.csv')

# %% [markdown]
# <h3>List of Columns in Dataframe</h3>

# %%
for cols in sorted(df):
    print(cols)
# Out:
# ethanol_all_drinks_gallons_per_capita
# ethanol_beer_gallons_per_capita
# ethanol_spirit_gallons_per_capita
# ethanol_wine_gallons_per_capita
# number_of_beers
# number_of_drinks_total
# number_of_glasses_wine
# number_of_shots_liquor
# state
# year

# %% [markdown]
# <h3>DataFrame Described</h3>

# %%
df.describe()
# Out:
#               year  ethanol_beer_gallons_per_capita  \
# count  2352.000000                      2352.000000
# mean   1997.500000                         1.279269
# std      12.123496                         0.228744
# min    1977.000000                         0.580000
# 25%    1987.000000                         1.120000
# 50%    1997.500000                         1.270000
# 75%    2008.000000                         1.400000
# max    2018.000000                         2.170000
#
#        ethanol_wine_gallons_per_capita  ethanol_spirit_gallons_per_capita  \
# count                      2352.000000                        2352.000000
# mean                          0.346144                           0.850391
# std                           0.182142                           0.347001
# min                           0.080000                           0.360000
# 25%                           0.210000                           0.650000
# 50%                           0.310000                           0.770000
# 75%                           0.450000                           0.960000
# max                           1.210000                           3.560000
#
#        ethanol_all_drinks_gallons_per_capita  number_of_beers  \
# count                            2352.000000      2352.000000
# mean                                2.476063       303.234064
# std                                 0.609605        54.220899
# min                                 1.190000       137.481481
# 25%                                 2.130000       265.481481
# 50%                                 2.360000       301.037037
# 75%                                 2.700000       331.851852
# max                                 6.320000       514.370370
#
#        number_of_glasses_wine  number_of_shots_liquor  number_of_drinks_total
# count             2352.000000             2352.000000             2352.000000
# mean                68.692085              176.561343              528.226757
# std                 36.145971               72.045606              130.049158
# min                 15.875969               74.744526              253.866667
# 25%                 41.674419              134.955393              454.400000
# 50%                 61.519380              159.870235              503.466667
# 75%                 89.302326              199.318735              576.000000
# max                240.124031              739.140308             1348.266667

# %% [markdown]
# <h3>First 10 Rows in DataFrame</h3>

# %%
df.head(10)
# Out:
#      state  year  ethanol_beer_gallons_per_capita  \
# 0  alabama  2018                             1.04
# 1  alabama  2017                             1.07
# 2  alabama  2016                             1.09
# 3  alabama  2015                             1.11
# 4  alabama  2014                             1.13
# 5  alabama  2013                             1.14
# 6  alabama  2012                             1.16
# 7  alabama  2011                             1.16
# 8  alabama  2010                             1.17
# 9  alabama  2009                             1.19
#
#    ethanol_wine_gallons_per_capita  ethanol_spirit_gallons_per_capita  \
# 0                             0.26                               0.69
# 1                             0.26                               0.67
# 2                             0.26                               0.65
# 3                             0.26                               0.64
# 4                             0.25                               0.62
# 5                             0.25                               0.60
# 6                             0.24                               0.60
# 7                             0.24                               0.59
# 8                             0.23                               0.58
# 9                             0.22                               0.57
#
#    ethanol_all_drinks_gallons_per_capita  number_of_beers  \
# 0                                   1.99       246.518519
# 1                                   1.99       253.629630
# 2                                   2.01       258.370370
# 3                                   2.01       263.111111
# 4                                   2.00       267.851852
# 5                                   1.99       270.222222
# 6                                   2.00       274.962963
# 7                                   1.98       274.962963
# 8                                   1.98       277.333333
# 9                                   1.98       282.074074
#
#    number_of_glasses_wine  number_of_shots_liquor  number_of_drinks_total
# 0               51.596899              143.260341              424.533333
# 1               51.596899              139.107867              424.533333
# 2               51.596899              134.955393              428.800000
# 3               51.596899              132.879157              428.800000
# 4               49.612403              128.726683              426.666667
# 5               49.612403              124.574209              424.533333
# 6               47.627907              124.574209              426.666667
# 7               47.627907              122.497972              422.400000
# 8               45.643411              120.421736              422.400000
# 9               43.658915              118.345499              422.400000

# %% [markdown]
# <h3>Values in 2015</h3>

# %%
df2 = df[df.loc[:, 'year'] == 2015]

# %%
df2.describe()
# Out:
#          year  ethanol_beer_gallons_per_capita  \
# count    56.0                        56.000000
# mean   2015.0                         1.149643
# std       0.0                         0.216551
# min    2015.0                         0.650000
# 25%    2015.0                         1.000000
# 50%    2015.0                         1.120000
# 75%    2015.0                         1.272500
# max    2015.0                         1.870000
#
#        ethanol_wine_gallons_per_capita  ethanol_spirit_gallons_per_capita  \
# count                        56.000000                          56.000000
# mean                          0.432143                           0.898750
# std                           0.207301                           0.283671
# min                           0.110000                           0.470000
# 25%                           0.287500                           0.747500
# 50%                           0.395000                           0.815000
# 75%                           0.530000                           0.972500
# max                           1.140000                           1.950000
#
#        ethanol_all_drinks_gallons_per_capita  number_of_beers  \
# count                              56.000000        56.000000
# mean                                2.480357       272.507937
# std                                 0.546423        51.330651
# min                                 1.400000       154.074074
# 25%                                 2.140000       237.037037
# 50%                                 2.360000       265.481481
# 75%                                 2.732500       301.629630
# max                                 4.700000       443.259259
#
#        number_of_glasses_wine  number_of_shots_liquor  number_of_drinks_total
# count               56.000000               56.000000               56.000000
# mean                85.758583              186.601784              529.142857
# std                 41.138708               58.896848              116.570232
# min                 21.829457               97.583131              298.666667
# 25%                 57.054264              155.198702              456.533333
# 50%                 78.387597              169.213301              503.466667
# 75%                105.178295              201.914031              582.933333
# max                226.232558              404.866180             1002.666667

# %% [markdown]
# <h3>Descending Sorted Values of Number of Drinks Total</h3>

# %%
df3 = df2.sort_values('number_of_drinks_total', ascending=False)

# %%
df3.head(10)
# Out:
#                      state  year  ethanol_beer_gallons_per_capita  \
# 1221         new hampshire  2015                             1.87
# 339   district of columbia  2015                             1.14
# 297               delaware  2015                             1.19
# 1179                nevada  2015                             1.39
# 1431          north dakota  2015                             1.58
# 1095               montana  2015                             1.63
# 1893               vermont  2015                             1.57
# 2061             wisconsin  2015                             1.39
# 507                  idaho  2015                             0.94
# 45                  alaska  2015                             1.11
#
#       ethanol_wine_gallons_per_capita  ethanol_spirit_gallons_per_capita  \
# 1221                             0.88                               1.95
# 339                              1.02                               1.67
# 297                              0.72                               1.75
# 1179                             0.66                               1.30
# 1431                             0.35                               1.33
# 1095                             0.50                               0.96
# 1893                             0.78                               0.73
# 2061                             0.39                               1.20
# 507                              1.14                               0.79
# 45                               0.53                               1.20
#
#       ethanol_all_drinks_gallons_per_capita  number_of_beers  \
# 1221                                   4.70       443.259259
# 339                                    3.82       270.222222
# 297                                    3.66       282.074074
# 1179                                   3.35       329.481481
# 1431                                   3.26       374.518519
# 1095                                   3.09       386.370370
# 1893                                   3.08       372.148148
# 2061                                   2.98       329.481481
# 507                                    2.87       222.814815
# 45                                     2.84       263.111111
#
#       number_of_glasses_wine  number_of_shots_liquor  number_of_drinks_total
# 1221              174.635659              404.866180             1002.666667
# 339               202.418605              346.731549              814.933333
# 297               142.883721              363.341444              780.800000
# 1179              130.976744              269.910787              714.666667
# 1431               69.457364              276.139497              695.466667
# 1095               99.224806              199.318735              659.200000
# 1893              154.790698              151.565288              657.066667
# 2061               77.395349              249.148418              635.733333
# 507               226.232558              164.022709              612.266667
# 45                105.178295              249.148418              605.866667

# %%
df3 = np.round(df3, decimals = 2)

# %% [markdown]
# <h3>Create Sorted List of Number of Drinks Total; Descending</h3>

# %%
df3.to_csv('../data/modified/number_of_drinks_total_sorted.csv')

# %% [markdown]
# <h3>List of Column Names</h3>

# %%
col = [i for i in sorted(df2.columns)]

# %%
col
# Out:
# ['ethanol_all_drinks_gallons_per_capita',
#  'ethanol_beer_gallons_per_capita',
#  'ethanol_spirit_gallons_per_capita',
#  'ethanol_wine_gallons_per_capita',
#  'number_of_beers',
#  'number_of_drinks_total',
#  'number_of_glasses_wine',
#  'number_of_shots_liquor',
#  'state',
#  'year']

# %% [markdown]
# <h3>DataFrame 2 Info</h3>

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56 entries, 3 to 2313
# Data columns (total 10 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   state                                  56 non-null     object
#  1   year                                   56 non-null     int64
#  2   ethanol_beer_gallons_per_capita        56 non-null     float64
#  3   ethanol_wine_gallons_per_capita        56 non-null     float64
#  4   ethanol_spirit_gallons_per_capita      56 non-null     float64
#  5   ethanol_all_drinks_gallons_per_capita  56 non-null     float64
#  6   number_of_beers                        56 non-null     float64
#  7   number_of_glasses_wine                 56 non-null     float64
#  8   number_of_shots_liquor                 56 non-null     float64
#  9   number_of_drinks_total                 56 non-null     float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 4.8+ KB

# %% [markdown]
# <h3>DataFrame 2 Description</h3>

# %%
df2.describe()
# Out:
#          year  ethanol_beer_gallons_per_capita  \
# count    56.0                        56.000000
# mean   2015.0                         1.149643
# std       0.0                         0.216551
# min    2015.0                         0.650000
# 25%    2015.0                         1.000000
# 50%    2015.0                         1.120000
# 75%    2015.0                         1.272500
# max    2015.0                         1.870000
#
#        ethanol_wine_gallons_per_capita  ethanol_spirit_gallons_per_capita  \
# count                        56.000000                          56.000000
# mean                          0.432143                           0.898750
# std                           0.207301                           0.283671
# min                           0.110000                           0.470000
# 25%                           0.287500                           0.747500
# 50%                           0.395000                           0.815000
# 75%                           0.530000                           0.972500
# max                           1.140000                           1.950000
#
#        ethanol_all_drinks_gallons_per_capita  number_of_beers  \
# count                              56.000000        56.000000
# mean                                2.480357       272.507937
# std                                 0.546423        51.330651
# min                                 1.400000       154.074074
# 25%                                 2.140000       237.037037
# 50%                                 2.360000       265.481481
# 75%                                 2.732500       301.629630
# max                                 4.700000       443.259259
#
#        number_of_glasses_wine  number_of_shots_liquor  number_of_drinks_total
# count               56.000000               56.000000               56.000000
# mean                85.758583              186.601784              529.142857
# std                 41.138708               58.896848              116.570232
# min                 21.829457               97.583131              298.666667
# 25%                 57.054264              155.198702              456.533333
# 50%                 78.387597              169.213301              503.466667
# 75%                105.178295              201.914031              582.933333
# max                226.232558              404.866180             1002.666667

# %% [markdown]
# <h3>Mean value of total number of drinks</h3>

# %%
# df_mean = df['number_of_drinks_total'].mean(axis = 0)
df_mean = df3["number_of_drinks_total"].mean()
df_mean = np.round(df_mean, decimals=2)

# %%
df_mean
# Out:
# 529.14

# %% [markdown]
# <h3>Places where Alcohol Consumption is above Average</h3>

# %%
above_average = df3.loc[df3['number_of_drinks_total'] > df_mean]

# %%
above_average
# Out:
#                      state  year  ethanol_beer_gallons_per_capita  \
# 1221         new hampshire  2015                             1.87
# 339   district of columbia  2015                             1.14
# 297               delaware  2015                             1.19
# 1179                nevada  2015                             1.39
# 1431          north dakota  2015                             1.58
# 1095               montana  2015                             1.63
# 1893               vermont  2015                             1.57
# 2061             wisconsin  2015                             1.39
# 507                  idaho  2015                             0.94
# 45                  alaska  2015                             1.11
# 1725          south dakota  2015                             1.49
# 801                  maine  2015                             1.37
# 213               colorado  2015                             1.12
# 2103               wyoming  2015                             1.25
# 969              minnesota  2015                             1.16
# 1557                oregon  2015                             1.23
# 381                florida  2015                             1.11
# 465                 hawaii  2015                             1.28
# 759              louisiana  2015                             1.27
# 1053              missouri  2015                             1.17
# 1641          rhode island  2015                             0.96
# 885          massachusetts  2015                             0.96
#
#       ethanol_wine_gallons_per_capita  ethanol_spirit_gallons_per_capita  \
# 1221                             0.88                               1.95
# 339                              1.02                               1.67
# 297                              0.72                               1.75
# 1179                             0.66                               1.30
# 1431                             0.35                               1.33
# 1095                             0.50                               0.96
# 1893                             0.78                               0.73
# 2061                             0.39                               1.20
# 507                              1.14                               0.79
# 45                               0.53                               1.20
# 1725                             0.29                               1.03
# 801                              0.44                               0.97
# 213                              0.51                               1.14
# 2103                             0.31                               1.18
# 969                              0.43                               1.14
# 1557                             0.58                               0.90
# 381                              0.51                               0.98
# 465                              0.56                               0.77
# 759                              0.33                               0.98
# 1053                             0.39                               0.97
# 1641                             0.57                               0.99
# 885                              0.65                               0.91
#
#       ethanol_all_drinks_gallons_per_capita  number_of_beers  \
# 1221                                   4.70           443.26
# 339                                    3.82           270.22
# 297                                    3.66           282.07
# 1179                                   3.35           329.48
# 1431                                   3.26           374.52
# 1095                                   3.09           386.37
# 1893                                   3.08           372.15
# 2061                                   2.98           329.48
# 507                                    2.87           222.81
# 45                                     2.84           263.11
# 1725                                   2.81           353.19
# 801                                    2.78           324.74
# 213                                    2.77           265.48
# 2103                                   2.74           296.30
# 969                                    2.73           274.96
# 1557                                   2.71           291.56
# 381                                    2.61           263.11
# 465                                    2.61           303.41
# 759                                    2.59           301.04
# 1053                                   2.53           277.33
# 1641                                   2.52           227.56
# 885                                    2.52           227.56
#
#       number_of_glasses_wine  number_of_shots_liquor  number_of_drinks_total
# 1221                  174.64                  404.87                 1002.67
# 339                   202.42                  346.73                  814.93
# 297                   142.88                  363.34                  780.80
# 1179                  130.98                  269.91                  714.67
# 1431                   69.46                  276.14                  695.47
# 1095                   99.22                  199.32                  659.20
# 1893                  154.79                  151.57                  657.07
# 2061                   77.40                  249.15                  635.73
# 507                   226.23                  164.02                  612.27
# 45                    105.18                  249.15                  605.87
# 1725                   57.55                  213.85                  599.47
# 801                    87.32                  201.39                  593.07
# 213                   101.21                  236.69                  590.93
# 2103                   61.52                  245.00                  584.53
# 969                    85.33                  236.69                  582.40
# 1557                  115.10                  186.86                  578.13
# 381                   101.21                  203.47                  556.80
# 465                   111.13                  159.87                  556.80
# 759                    65.49                  203.47                  552.53
# 1053                   77.40                  201.39                  539.73
# 1641                  113.12                  205.55                  537.60
# 885                   128.99                  188.94                  537.60

# %% [markdown]
# <h3>Create CSV File for Above Average Findings</h3>

# %%
above_average.to_csv('../data/modified/above_averge.csv')
