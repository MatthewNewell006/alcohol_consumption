# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from cycler import cycler
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../data/pov_table3.xls')

# %%
df.head(5)
# Out:
#   Table with row headings in column A and column headings in rows 6 to 9.  \
# 0                                           Table 3.
# 1  People in Poverty by Selected Characteristics:...
# 2                                                NaN
# 3  (Numbers in thousands, margin of error in thou...
# 4                                     Characteristic
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4       2014        NaN        NaN        NaN        NaN       2015
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN         NaN
#
#                              Unnamed: 11 Unnamed: 12
# 0                                    NaN         NaN
# 1                                    NaN         NaN
# 2                                    NaN         NaN
# 3                                    NaN         NaN
# 4  Change in poverty (2015 less 2014)2,*         NaN

# %%
df.dropna(inplace=True)

# %%
df.head(5)
# Out:
#    Table with row headings in column A and column headings in rows 6 to 9.  \
# 9                      Total.................……………………
# 12               In families..............………………………..
# 13                   Householder............…………………….
# 14              Related children under age 18………………..
# 15                Related children under age 6…………………
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 9      315804      46657        857       14.8        0.3     318454
# 12     256308      32615        741       12.7        0.3     258121
# 13      81730       9467        228       11.6        0.3      82199
# 14      72383      14987        403       20.7        0.6      72558
# 15      23470       5504        197       23.5        0.8      23459
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 9       43123        926       13.5         0.3     *-3,534       *-1.2
# 12      29893        844       11.6         0.3     *-2,722       *-1.1
# 13       8589        243       10.4         0.3       *-879       *-1.1
# 14      13962        441       19.2         0.6     *-1,025       *-1.5
# 15       4923        201         21         0.8       *-582       *-2.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44 entries, 9 to 72
# Data columns (total 13 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Table with row headings in column A and column headings in rows 6 to 9.  44 non-null     object
#  1   Unnamed: 1                                                               44 non-null     object
#  2   Unnamed: 2                                                               44 non-null     object
#  3   Unnamed: 3                                                               44 non-null     object
#  4   Unnamed: 4                                                               44 non-null     object
#  5   Unnamed: 5                                                               44 non-null     object
#  6   Unnamed: 6                                                               44 non-null     object
#  7   Unnamed: 7                                                               44 non-null     object
#  8   Unnamed: 8                                                               44 non-null     object
#  9   Unnamed: 9                                                               44 non-null     object
#  10  Unnamed: 10                                                              44 non-null     object
#  11  Unnamed: 11                                                              44 non-null     object
#  12  Unnamed: 12                                                              44 non-null     object
# dtypes: object(13)
# memory usage: 4.8+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44 entries, 9 to 72
# Data columns (total 13 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Table with row headings in column A and column headings in rows 6 to 9.  44 non-null     object
#  1   Unnamed: 1                                                               44 non-null     object
#  2   Unnamed: 2                                                               44 non-null     object
#  3   Unnamed: 3                                                               44 non-null     object
#  4   Unnamed: 4                                                               44 non-null     object
#  5   Unnamed: 5                                                               44 non-null     object
#  6   Unnamed: 6                                                               44 non-null     object
#  7   Unnamed: 7                                                               44 non-null     object
#  8   Unnamed: 8                                                               44 non-null     object
#  9   Unnamed: 9                                                               44 non-null     object
#  10  Unnamed: 10                                                              44 non-null     object
#  11  Unnamed: 11                                                              44 non-null     object
#  12  Unnamed: 12                                                              44 non-null     object
# dtypes: object(13)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#        Table with row headings in column A and column headings in rows 6 to 9.  \
# count                                                  44
# unique                                                 43
# top                       Total, aged 18 to 64……..….……………
# freq                                                    2
#
#         Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# count           44          44          44        44.0        44.0
# unique          42          42          41        38.0        14.0
# top         196254       26527         533        13.5         0.3
# freq             3           3           3         3.0        14.0
#
#         Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# count           44          44          44        44.0         44.0
# unique          42          42          40        40.0         12.0
# top         197260       24414         566        12.4          0.3
# freq             3           3           3         4.0         14.0
#
#        Unnamed: 11 Unnamed: 12
# count           44          44
# unique          39          24
# top              N       *-1.1
# freq             4           8
