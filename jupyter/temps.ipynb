# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from cycler import cycler
import matplotlib.pyplot as plt

# %%
temp_df = pd.read_excel('../data/Highest temperature on record through 2015 by US City.xlsx')

# %%
temp_df
# Out:
#                           CITY  JAN  FEB  MAR  APR    MAY  JUN  JUL  AUG  SEP  \
# 0                BIRMINGHAM,AL   81   83   89   92   99.0  106  107  105  102
# 1                HUNTSVILLE,AL   77   83   88   92   96.0  106  105  105  101
# 2                    MOBILE,AL   84   84   89   94  100.0  103  104  105   99
# 3                MONTGOMERY,AL   83   85   89   94   98.0  105  105  106  101
# 4                 ANCHORAGE,AK   50   49   51   69   77.0   85   84   82   73
# ..                         ...  ...  ...  ...  ...    ...  ...  ...  ...  ...
# 258   PAGO PAGO- AMER SAMOA,PC   95   96   95   95   93.0   95   91   92   92
# 259   POHNPEI- CAROLINE IS.,PC   94   96   94   94   94.0   94   95   97   96
# 260  CHUUK- E. CAROLINE IS.,PC   94   95   96   94   93.0   93   92   96   93
# 261     YAP- W CAROLINE IS.,PC   94   96   93   96   96.0   97   94   95   96
# 262                SAN JUAN,PR   92   96   96   97   96.0   97   95   97   97
#
#      OCT  NOV  DEC  ANN
# ...

# %%
# temp_df.to_csv('../data/Highest temperature on record through 2015 by US City.txt')

# %%
temp_df['STATE'] = temp_df['CITY'].apply(lambda x: x.split(',')[-1])

# %%
temp_df
# Out:
#                           CITY  JAN  FEB  MAR  APR    MAY  JUN  JUL  AUG  SEP  \
# 0                BIRMINGHAM,AL   81   83   89   92   99.0  106  107  105  102
# 1                HUNTSVILLE,AL   77   83   88   92   96.0  106  105  105  101
# 2                    MOBILE,AL   84   84   89   94  100.0  103  104  105   99
# 3                MONTGOMERY,AL   83   85   89   94   98.0  105  105  106  101
# 4                 ANCHORAGE,AK   50   49   51   69   77.0   85   84   82   73
# ..                         ...  ...  ...  ...  ...    ...  ...  ...  ...  ...
# 258   PAGO PAGO- AMER SAMOA,PC   95   96   95   95   93.0   95   91   92   92
# 259   POHNPEI- CAROLINE IS.,PC   94   96   94   94   94.0   94   95   97   96
# 260  CHUUK- E. CAROLINE IS.,PC   94   95   96   94   93.0   93   92   96   93
# 261     YAP- W CAROLINE IS.,PC   94   96   93   96   96.0   97   94   95   96
# 262                SAN JUAN,PR   92   96   96   97   96.0   97   95   97   97
#
#      OCT  NOV  DEC  ANN STATE
# ...

# %%
# temp_df.to_csv('../data/highest_temp_modified_1.txt')

# %%
ann_mean = temp_df.groupby('STATE', as_index=False)['ANN'].agg('mean')
print(ann_mean)
# Out:
#                   STATE         ANN
# 0                    AK   87.550000
# 1                    AL  106.000000
# 2                    AR  114.500000
# 3                    AZ  111.750000
# 4                    CA  110.153846
# 5                    CO  103.200000
# 6                    CT  103.000000
# 7                    DC  105.000000
# 8                    DE  103.000000
# 9                    FL  101.666667
# 10                   GA  107.000000
# 11                   HI   94.250000
# 12                   IA  105.500000
# 13                   ID  110.000000
# 14                   IL  106.000000
# 15                   IN  106.750000
# 16                   KS  112.600000
# 17  KWAJALEIN- MARSHALL   97.000000
# 18                   KY  106.500000
# 19                   LA  105.750000
# 20                   MA  101.000000
# 21                   MD  106.000000
# 22                   ME   99.500000
# 23                   MI  102.250000
# 24                   MN  103.200000
# ...

# %%
ann_mean.reset_index(drop = True)
# Out:
#                   STATE         ANN
# 0                    AK   87.550000
# 1                    AL  106.000000
# 2                    AR  114.500000
# 3                    AZ  111.750000
# 4                    CA  110.153846
# 5                    CO  103.200000
# 6                    CT  103.000000
# 7                    DC  105.000000
# 8                    DE  103.000000
# 9                    FL  101.666667
# 10                   GA  107.000000
# 11                   HI   94.250000
# 12                   IA  105.500000
# 13                   ID  110.000000
# 14                   IL  106.000000
# 15                   IN  106.750000
# 16                   KS  112.600000
# 17  KWAJALEIN- MARSHALL   97.000000
# 18                   KY  106.500000
# 19                   LA  105.750000
# 20                   MA  101.000000
# 21                   MD  106.000000
# 22                   ME   99.500000
# 23                   MI  102.250000
# 24                   MN  103.200000
# ...

# %%
# ann_mean.drop(ann_mean[ann_mean['STATE'].apply(lambda x: len(x.split('-')) > 2)])
ann_mean = ann_mean[ann_mean['STATE'].map(len) == 2]
ann_mean.head(20)
# Out:
#    STATE         ANN
# 0     AK   87.550000
# 1     AL  106.000000
# 2     AR  114.500000
# 3     AZ  111.750000
# 4     CA  110.153846
# 5     CO  103.200000
# 6     CT  103.000000
# 7     DC  105.000000
# 8     DE  103.000000
# 9     FL  101.666667
# 10    GA  107.000000
# 11    HI   94.250000
# 12    IA  105.500000
# 13    ID  110.000000
# 14    IL  106.000000
# 15    IN  106.750000
# 16    KS  112.600000
# 18    KY  106.500000
# 19    LA  105.750000
# 20    MA  101.000000

# %%
ann_mean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 0 to 53
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   STATE   53 non-null     object
#  1   ANN     53 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.2+ KB

# %%
ann_mean = np.round(ann_mean, 2)b

# %%
ann_mean
# Out:
#    STATE     ANN
# 0     AK   87.55
# 1     AL  106.00
# 2     AR  114.50
# 3     AZ  111.75
# 4     CA  110.15
# 5     CO  103.20
# 6     CT  103.00
# 7     DC  105.00
# 8     DE  103.00
# 9     FL  101.67
# 10    GA  107.00
# 11    HI   94.25
# 12    IA  105.50
# 13    ID  110.00
# 14    IL  106.00
# 15    IN  106.75
# 16    KS  112.60
# 18    KY  106.50
# 19    LA  105.75
# 20    MA  101.00
# 21    MD  106.00
# 22    ME   99.50
# 23    MI  102.25
# 24    MN  103.20
# 25    MO  112.00
# 26    MS  107.00
# 27    MT  107.14
# 28    NC  102.17
# 29    ND  108.00
# 30    NE  111.14
# 31    NH   87.00
# 32    NJ  107.00
# 33    NM  108.67
# 34    NV  108.40
# 35    NY  100.33
# 36    OH  102.88
# 37    OK  113.00
# 38    OR  106.38
# 39    PA  102.71
# 40    PC   96.14
# 41    PR   98.00
# 42    RI  104.00
# 43    SC  106.67
# 44    SD  112.00
# 45    TN  106.17
# 46    TX  111.06
# 47    UT  107.00
# 48    VA  104.00
# 49    VT  101.00
# 50    WA  106.33
# 51    WI  104.75
# ...

# %%
# ann_mean.to_csv('../data/ann_mean.csv')
# ann_mean.to_csv('../data/ann_mean.txt', sep = '\t')
