# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot

# %% [markdown]
# <h3>Import Alcohol Dataframe</h3>

# %%
ac_df = pd.read_csv('../data/modified/2015_alcohol_stats.csv')
ac_df.head(11)
# Out:
#     Unnamed: 0                 state  year  ethanol_beer_gallons_per_capita  \
# 0            0               alabama  2015                             1.11
# 1            1                alaska  2015                             1.11
# 2            2               arizona  2015                             1.16
# 3            3              arkansas  2015                             0.97
# 4            4            california  2015                             1.00
# 5            5              colorado  2015                             1.12
# 6            6           connecticut  2015                             0.85
# 7            7              delaware  2015                             1.19
# 8            8  district of columbia  2015                             1.14
# 9            9               florida  2015                             1.11
# 10          10               georgia  2015                             1.01
#
# ...
