# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from cycler import cycler
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../data/pov_table6.xls')

# %%
df.head(5)
# Out:
#   Table with row headings in column A and column headings in rows 6 to 9.  \
# 0                                           Table 6.
# 1  Income Deficit or Surplus of Families and Unre...
# 2                                                NaN
# 3  (Numbers of families and unrelated individuals...
# 4                                     Characteristic
#
#   Unnamed: 1                  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN                         NaN        NaN        NaN        NaN
# 1        NaN                         NaN        NaN        NaN        NaN
# 2        NaN                         NaN        NaN        NaN        NaN
# 3        NaN                         NaN        NaN        NaN        NaN
# 4      Total  Size of deficit or surplus        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN
# ...

# %%
df.dropna(inplace=True)

# %%
df.head(5)
# Out:
#    Table with row headings in column A and column headings in rows 6 to 9.  \
# 11                         All families …………………………………
# 12                  Married-couple families …...………….
# 14                        no husband present…………………..
# 16                           no wife present………………………
# 17                     Unrelated individuals…..………………
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 11    8588.77    482.001    835.707    1304.47    1183.95    885.813
# 12    3245.22    242.404     376.19    556.005    409.653    339.409
# 14    4404.33    180.002    338.962     603.41    636.787    447.792
# 16    939.212    59.5949    120.555    145.054    137.507    98.6116
# 17    12671.4    1311.86    1985.06    2346.61    1209.43    897.303
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 11    805.674    839.699    2251.46     10118.3      177.64     2907.14
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 11 to 27
# Data columns (total 14 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Table with row headings in column A and column headings in rows 6 to 9.  10 non-null     object
#  1   Unnamed: 1                                                               10 non-null     object
#  2   Unnamed: 2                                                               10 non-null     object
#  3   Unnamed: 3                                                               10 non-null     object
#  4   Unnamed: 4                                                               10 non-null     object
#  5   Unnamed: 5                                                               10 non-null     object
# ...

# %%
df.describe()
# Out:
#        Table with row headings in column A and column headings in rows 6 to 9.  \
# count                                                  10
# unique                                                 10
# top                    Married-couple families …...…………..
# freq                                                    1
#
#         Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# count       10.000     10.0000    10.00000    10.00000     10.0000
# unique      10.000     10.0000    10.00000    10.00000     10.0000
# top      12671.395   1311.8583   105.85312   671.83708   1183.9463
# freq         1.000      1.0000     1.00000     1.00000      1.0000
#
#         Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# count     10.00000    10.00000    10.00000      10.000      10.0000
# unique    10.00000    10.00000    10.00000      10.000      10.0000
# top      447.79207   239.25997   350.29961   63294.979    9455.7854
# ...
