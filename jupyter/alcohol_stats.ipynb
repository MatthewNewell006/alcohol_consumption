# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from cycler import cycler
import matplotlib.pyplot as plt
# import re

# %% [markdown]
# <h3>Import Alcohol Dataframe</h3>

# %%
ac_df = pd.read_csv('../data/modified/2015_states_sorted.csv')

# %%
ac_df.head(10)
# Out:
#    Unnamed: 0                 state  year  ethanol_beer_gallons_per_capita  \
# 0           3               alabama  2015                             1.11
# 1          45                alaska  2015                             1.11
# 2          87               arizona  2015                             1.16
# 3         129              arkansas  2015                             0.97
# 4         171            california  2015                             1.00
# 5         213              colorado  2015                             1.12
# 6         255           connecticut  2015                             0.85
# 7         297              delaware  2015                             1.19
# 8         339  district of columbia  2015                             1.14
# 9         381               florida  2015                             1.11
#
#    ethanol_wine_gallons_per_capita  ethanol_spirit_gallons_per_capita  \
# 0                             0.26                               0.64
# 1                             0.53                               1.20
# 2                             0.40                               0.78
# 3                             0.22                               0.65
# 4                             0.53                               0.75
# 5                             0.51                               1.14
# 6                             0.61                               0.95
# 7                             0.72                               1.75
# 8                             1.02                               1.67
# 9                             0.51                               0.98
#
#    ethanol_all_drinks_gallons_per_capita  number_of_beers  \
# 0                                   2.01       263.111111
# 1                                   2.84       263.111111
# 2                                   2.34       274.962963
# 3                                   1.83       229.925926
# 4                                   2.28       237.037037
# 5                                   2.77       265.481481
# 6                                   2.41       201.481481
# 7                                   3.66       282.074074
# 8                                   3.82       270.222222
# 9                                   2.61       263.111111
#
#    number_of_glasses_wine  number_of_shots_liquor  number_of_drinks_total
# 0               51.596899              132.879157              428.800000
# 1              105.178295              249.148418              605.866667
# 2               79.379845              161.946472              499.200000
# 3               43.658915              134.955393              390.400000
# 4              105.178295              155.717762              486.400000
# 5              101.209302              236.690998              590.933333
# 6              121.054264              197.242498              514.133333
# 7              142.883721              363.341444              780.800000
# 8              202.418605              346.731549              814.933333
# 9              101.209302              203.471208              556.800000

# %% [markdown]
# <h3>Modify Alcohol DataFrame</h3>

# %%
ac_df = ac_df.drop(['Unnamed: 0'], axis = 1)

# %%
ac_df.head(10)
# Out:
#                   state  year  ethanol_beer_gallons_per_capita  \
# 0               alabama  2015                             1.11
# 1                alaska  2015                             1.11
# 2               arizona  2015                             1.16
# 3              arkansas  2015                             0.97
# 4            california  2015                             1.00
# 5              colorado  2015                             1.12
# 6           connecticut  2015                             0.85
# 7              delaware  2015                             1.19
# 8  district of columbia  2015                             1.14
# 9               florida  2015                             1.11
#
#    ethanol_wine_gallons_per_capita  ethanol_spirit_gallons_per_capita  \
# 0                             0.26                               0.64
# 1                             0.53                               1.20
# 2                             0.40                               0.78
# 3                             0.22                               0.65
# 4                             0.53                               0.75
# 5                             0.51                               1.14
# 6                             0.61                               0.95
# 7                             0.72                               1.75
# 8                             1.02                               1.67
# 9                             0.51                               0.98
#
#    ethanol_all_drinks_gallons_per_capita  number_of_beers  \
# 0                                   2.01       263.111111
# 1                                   2.84       263.111111
# 2                                   2.34       274.962963
# 3                                   1.83       229.925926
# 4                                   2.28       237.037037
# 5                                   2.77       265.481481
# 6                                   2.41       201.481481
# 7                                   3.66       282.074074
# 8                                   3.82       270.222222
# 9                                   2.61       263.111111
#
#    number_of_glasses_wine  number_of_shots_liquor  number_of_drinks_total
# 0               51.596899              132.879157              428.800000
# 1              105.178295              249.148418              605.866667
# 2               79.379845              161.946472              499.200000
# 3               43.658915              134.955393              390.400000
# 4              105.178295              155.717762              486.400000
# 5              101.209302              236.690998              590.933333
# 6              121.054264              197.242498              514.133333
# 7              142.883721              363.341444              780.800000
# 8              202.418605              346.731549              814.933333
# 9              101.209302              203.471208              556.800000

# %%
# ac_df.to_csv('../data/modified/2015_alcohol_stats.csv')

# %% [markdown]
# <h3>Import Temp DataFrame</h3>

# %%
t_df = pd.read_csv('../data/modified/2015_state_temperatures.csv')

# %%
t_df
# Out:
#      Unnamed: 0  JAN  FEB  MAR  APR    MAY  JUN  JUL  AUG  SEP  OCT  NOV  DEC  \
# 0             0   81   83   89   92   99.0  106  107  105  102   94   85   80
# 1             1   77   83   88   92   96.0  106  105  105  101   91   84   79
# 2             2   84   84   89   94  100.0  103  104  105   99   93   87   81
# 3             3   83   85   89   94   98.0  105  105  106  101  100   88   85
# 4             4   50   49   51   69   77.0   85   84   82   73   64   54   48
# ..          ...  ...  ...  ...  ...    ...  ...  ...  ...  ...  ...  ...  ...
# 258         258   95   96   95   95   93.0   95   91   92   92   94   95   94
# 259         259   94   96   94   94   94.0   94   95   97   96   95   98   95
# 260         260   94   95   96   94   93.0   93   92   96   93   92   91   93
# 261         261   94   96   93   96   96.0   97   94   95   96   96   94   94
# 262         262   92   96   96   97   96.0   97   95   97   97   98   96   94
#
#      ANN
# 0    107
# 1    106
# 2    105
# 3    106
# 4     85
# ..   ...
# 258   96
# 259   98
# 260   96
# 261   97
# 262   98
#
# [263 rows x 14 columns]
